# %%
# plots GBOV validation of leaf

# %%
# import packages
import folium
import time
from folium import plugins
import numpy as np
import matplotlib.pyplot as plt

# %%
# main function to plot data
# currently hardcodes ratio of LAI/PAI for each IGBP class , need to make this a dictionary
# uncertainties originally given as a range are converted to 1 sigma by dividing range by 4 - implies range if 95%ile coverage of residuals
# uncertainties are combined assuming indpenedence
def plotDataDGBOV(dataListDASF,dataList,xvar,yvar,percentile,fileName,gain,fig):
    laiName = 'LAI_Warren'
    if xvar == laiName :
        plt.plot([0,6],[0,6],'k--')
        plt.ylim(0,6)
        plt.xlim(0,6)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.75*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.75),np.maximum(1.25*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.75),color = 'gray',alpha = 0.1)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.80*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.50),np.maximum(1.20*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.50),color = 'gray',alpha = 0.3)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.85*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.25),np.maximum(1.15*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.25),color = 'gray',alpha = 0.5)
        plt.ylabel('LAI SL2P')
        plt.xlabel('LAI In-Situ')
    elif yvar == 'sampleDASF' :
        plt.plot([0,6],[0,6],'k--')
        plt.ylim(0,1)
        plt.xlim(0,6)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.75*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.75),np.maximum(1.25*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.75),color = 'gray',alpha = 0.1)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.80*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.50),np.maximum(1.20*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.50),color = 'gray',alpha = 0.3)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.85*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.25),np.maximum(1.15*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.25),color = 'gray',alpha = 0.5)
        plt.ylabel(' SL2P')
        plt.xlabel('LAI In-Situ')
    elif xvar == "fcover_Total" : 
        plt.plot([0,1],[0,1],'k--')
        plt.ylim(0,1)
        plt.xlim(0,1)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.8*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.10),np.maximum(1.2*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.10),color = 'gray',alpha = 0.1)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.85*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.075),np.maximum(1.15*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.075),color = 'gray',alpha = 0.3)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.90*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.05),np.maximum(1.10*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.05),color = 'gray',alpha = 0.5)
        plt.ylabel('FCOVER SL2P')
        plt.xlabel('FCOVER In-Situ')
    elif xvar == 'fIPAR' :
        plt.plot([0,1],[0,1],'k--')
        plt.ylim(0,1)
        plt.xlim(0,1)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.8*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.10),np.maximum(1.2*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.10),color = 'gray',alpha = 0.1)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.85*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.075),np.maximum(1.15*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.075),color = 'gray',alpha = 0.3)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.95*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.05),np.maximum(1.05*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.05),color = 'gray',alpha = 0.5)
        plt.ylabel('FAPAR SL2P')
        plt.xlabel('FIPAR In-Situ')
    elif  xvar == 'LAIe_Miller' :
        plt.plot([0,4],[0,4],'k--')
        plt.ylim(0,4)
        plt.xlim(0,4)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.75*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.75),np.maximum(1.25*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.75),color = 'gray',alpha = 0.1)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.80*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.50),np.maximum(1.20*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.50),color = 'gray',alpha = 0.3)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.85*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.25),np.maximum(1.15*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.25),color = 'gray',alpha = 0.5)
        plt.ylabel('LAIe SL2P')
        plt.xlabel('LAIe In-Situ')
    else :
        plt.plot([0,1],[0,1],'k--')
        plt.ylim(0,1)
        plt.xlim(0,1)
        
    error = np.zeros(len(dataList))
    correct = np.zeros(len(dataList)) 
    dasfALL = np.zeros(len(dataList))
    laiALL = np.zeros(len(dataList))    
    count = 0
    for n in range(0,len(dataList)) :
    #for n in range(0,1) :
        
        # check there is satellite data
        if ( (dataList[n][yvar])[2]['data'] ) :

            # get estimate and stdErr
            est = np.array((dataList[n][yvar])[2]['data'])
            stdError = np.array((dataList[n][yvar])[5]['data'])
                        
            # screen in situ data
            if ((dataList[n][xvar+'_down'] != -999 ) or (dataList[n][xvar+'_up'] != -999 )) and ((dataList[n]['up_flag'] == 0 ) and (dataList[n]['down_flag'] == 0 ))  \
                        and ( (dataList[n]['IGBP_class'] == 'Mixed Forest') or (dataList[n]['IGBP_class'] == 'Woody Savannas') or (dataList[n]['IGBP_class'] == 'Deciduous Broadleaf' ) or (dataList[n]['IGBP_class'] == 'Closed Shrublands') ) :
            
                #set symbol size and colour, alpha = LAI/PAI ratio and alphaError=standard error of alpha 
                if (yvar == 'samplefAPAR') :
                    symbolSize = 10
                else :
                    # we use Miller clumping as it averages all zenith angles
                    if ( (dataList[n][xvar+'_up'] != -999 ) and (dataList[n][xvar+'_down'] != -999 )) :
                        clumping = ((dataList[n]['LAI_Miller_up'] * (dataList[n]['clumping_Miller_up']))+ (dataList[n]['clumping_Miller_down'] * (dataList[n]['clumping_Miller_down'])))/(dataList[n]['LAI_Miller_up'] + (dataList[n]['LAI_Miller_down']))
                    elif  (dataList[n][xvar+'_up'] != -999 ) :
                        clumping = dataList[n]['LAI_Miller_up'] 
                    else :
                        clumping = dataList[n]['LAI_Miller_down'] 
                    symbolSize = 20* (1-clumping)      
                    
                if dataList[n]['IGBP_class']== 'Mixed Forest':
                    symbolColour = 'y'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Woody Savannas':
                    symbolColour = 'b'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Evergreen Broadleaf':
                    symbolColour = 'r'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Deciduous Broadleaf':
                    symbolColour = 'r'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Evergreen Needleleaf':
                    symbolColour = 'b'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Deciduous Needleaf':
                    symbolColour = 'b'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Croplands':
                    symbolColour = 'm'       
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Cropland Mosaics':
                    symbolColour = 'm'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Grasslands':
                    symbolColour = 'm'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Grassland':
                    symbolColour = 'm'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Closed Shrublands':
                    symbolColour = 'm'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Open Shrublands':
                    symbolColour = 'm'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Savannas':
                    symbolColour = 'm'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Permanent Wetlands':
                    symbolColour = 'k'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Tundra':
                    symbolColour = 'k'
                    alpha = 0.84
                    alphaError = 0.11
                else :
                    print(dataList[n]['IGBP_class'])
                    symbolColour = 'g'
                    alpha = 0.84
                    alphaError = 0.11
                if dataList[n]['Site'] == 'BartlettExperimentalForest' :
                    alpha = 0.76 # from https://www.researchgate.net/publication/
#                     symbolColour = 'm'
                                # 8688598_Assessing_seasonal_leaf_area_dynamics_and_vertical_leaf_area_distribution_in_eastern_white_pine_Pinus_strobus_L_with_a_portable_light_meter/link/55cdd7ee08ae502646a4c393/download
                elif  dataList[n]['Site'] == 'HarvardForest' :
                    alpha = 0.81 # https://www.sciencedirect.com/science/article/pii/S0168192318302351#sec0055
#                     symbolColour = 'k'
                elif dataList[n]['Site'] == 'OakRidge' :
                    alpha = 0.85 # https://link.springer.com/article/10.1007%2Fs00468-011-0568-4
#                     symbolColour = 'c'
                elif dataList[n]['Site'] == 'TalladegaNationalForest':
#                     symbolColour = 'g'
                    alpha = 0.875 # Sampson et al. 2011
                elif dataList[n]['Site'] == 'Underc':
#                     symbolColour = 'aquamarine'
                    alpha = 0.92  # visual
                elif dataList[n]['Site'] == 'SteigerwaldtLandServices':
#                     symbolColour = 'forestgreen'
                    alpha = 0.875 # Sampson et al. 2011
                elif dataList[n]['Site'] == 'OrdwaySwisherBiologicalStation':
#                     symbolColour = 'orange'
                    alpha = 0.875 # Shrub
                # determine reference value, different for LAI vs fAPAR
                # determine reference value, different for LAI vs fAPAR
                xup = 0
                xerror = 0
                xerrorup = 0
                xerrordown = 0
                
                if (yvar == 'samplefAPAR') :
                
                    # check if up 
                    if (dataList[n]['FIPAR_up'] != -999 ) :
                    
                        # get up and its error 
                        xup = float(dataList[n]['FIPAR_up']) 
                        if (dataList[n]['FIPAR_up_err'] != -999 ) :
                            xerrorup = (float(dataList[n]['FIPAR_up_err']))**2

                       
                        # check if also down
                        if (dataList[n]['FIPAR_down'] != -999 ) :
                        
                            # also down
                            xdown =  ( 1 - xup) * float(dataList[n]['FIPAR_down'])  
                            if (dataList[n]['FIPAR_down_err'] != -999 ) :
                                xerrordown = (float(dataList[n]['FIPAR_down_err']))**2 

                                 
                        # convert to fAPAR and factor in uncertainty of alpha in xerrorup
                        xup = alpha * xup
                        alphaError = 0
                        xerrorup = (xerrorup + (alphaError * xup)**(2))
                        
                    else :
                        # only down 
                        xdown = float(dataList[n]['FIPAR_down']) 
                        if ( dataList[n]['FIPAR_down_err'] != -999 ) :
                            xerrordown = float(dataList[n]['FIPAR_down_err'])**2  
                    x = alpha * xup + xdown
                    xerror = (max(0,((xup*xerrorup+xdown*xerrordown)/(xup+xdown))))**0.5
                    if (xerror <= 0 ) :
                        xerror = 0.1 * x
                        
                    if ( gain>0) :
                        dasf =  np.array((dataListDASF[n]['sampleDASF'])[2]['data'])

                        
                        if dataList[n]['IGBP_class'] ==  'Evergreen Needleleaf':
                            if (yvar == 'sampleLAI') : 
                                #estDASF = np.exp(0.023505*(np.power(np.log(dasf),2)) + 1.7414*np.log(dasf) + 2.7345)
                                #stdErrorDASF = 14.289*np.power(dasf,2)+4.2901*dasf-0.19569
                                estDASF = np.exp(-0.30661*(np.power(np.log(dasf),2)) + 0.63965*np.log(dasf) + 2.1727)
                                stdErrorDASF = -4.4172*np.power(dasf,2)+19.754*dasf-1.196  
                            elif (yvar == 'samplefAPAR') : 
                                z = np.log(dasf+0.01)-0.01
                                estDASF = -0.0013627*np.power(z,2)+0.22376*z+0.92611+0.2*dasf
                                stdErrorDASF = 0.88147*np.power(dasf,2)-0.5598*dasf+0.17837
                            elif (yvar =='samplefCOVER') :
                                estDASF = np.exp(-0.37245*(np.power(np.log(dasf),2)) + -0.064641*np.log(dasf) + 0.074017)
                                stdErrorDASF = -1.0603*np.power(dasf,2)+1.6887*dasf-0.037161   
                        elif dataList[n]['IGBP_class']== 'Mixed Forest' :
                            # old ones with bad clumping
                            #estDASF = np.exp(-0.0026808*(np.power(np.log(dasf),2)) + 1.4776*np.log(dasf) + 2.2686)
                            #stdErrorDASF = 4.7536*np.power(dasf,2)+4.2083*dasf-0.18081  
                            if (yvar == 'sampleLAI') : 
                                estDASF = np.exp(-0.2668*(np.power(np.log(dasf),2)) + 0.78615*np.log(dasf) + 2.2227)
                                stdErrorDASF = -0.83481*np.power(dasf,2)+8.2123*dasf-0.51067  
                            elif (yvar == 'samplefAPAR') : 
                                z = np.log(dasf+0.01)-0.05
                                estDASF = -0.030564*np.power(z,2)+0.070905*z+0.77337+0.15*dasf
                                stdErrorDASF = 0.65692*np.power(dasf,2)-0.70076*dasf+0.23981
                            elif (yvar == 'samplefCOVER') :
                                estDASF = np.exp(-0.36752*(np.power(np.log(dasf),2)) + -0.036441*np.log(dasf) + 0.077569)
                                stdErrorDASF = -0.94729*np.power(dasf,2)+1.5343*dasf-0.035862 
                        else :
                            if (yvar == 'sampleLAI') : 
                                estDASF = np.exp(-0.39812*(np.power(np.log(dasf),2)) + 0.33646*np.log(dasf) + 2.082)
                                stdErrorDASF = -1.6748*np.power(dasf,2)+16.484*dasf-1.025  
                                #estDASF = np.exp(2.443e-5*(np.power(np.log(dasf),2)) + 1.578*np.log(dasf) + 2.383)
                                #stdErrorDASF = 7.4952*np.power(dasf,2)+4.4447*dasf-0.22168
                            elif (yvar == 'samplefAPAR') : 
                                z = np.log(dasf+0.01)-0.05
                                estDASF = -0.030564*np.power(z,2)+0.070905*z+0.77337+0.15*dasf
                                stdErrorDASF = 0.65692*np.power(dasf,2)-0.70076*dasf+0.23981
                            elif (yvar == 'samplefCOVER') :
                                estDASF = np.exp(-0.41105*(np.power(np.log(dasf),2)) + -0.18412*np.log(dasf) + 0.040711)
                                stdErrorDASF = -1.2707*np.power(dasf,2)+1.9159*dasf-0.040718                                 
                        #m1 = est
                        #v1 = np.power(stdError,2)
                        #m2 = estDASF
                        #v2 = np.power(stdErrorDASF,2)/gain
                        #est = (m1*v2+m2*v1)/(v1+v2)
                        #stdError = (v1*v2)/(v1+v2)
                        est = estDASF
                        stdError = stdErrorDASF
                    
                    # determine residuals for each satellite matchup
                    residual = est-x
                    residualAbs = np.absolute(residual)

                    # only use good matches for stats
                    index = np.where(residualAbs<=np.percentile(residualAbs,percentile))
                    filteredresiduals = residual[index[0]]
                    yerror = stdError[index[0]]/5

                    #print(filteredresiduals)
                    y = x + np.median(filteredresiduals)
                    yerror = np.median(yerror)
                    yerror = ((np.ptp(filteredresiduals)/4/(len(residual)**0.5))**2 +  yerror**2)**0.5 #
                    
                    if (x>0) and (x<1) and (y>0) and ( y < 1 ):
                        count = count + 1
                        error[count] = np.median(filteredresiduals)
                        correct[count] = np.absolute(error[count])<np.maximum(0.20*x,0.10)
                        plt.plot(x,y,'o',markersize =symbolSize,markerfacecolor=symbolColour,markeredgecolor='k' )
                        plt.errorbar(x,y,yerr=yerror,xerr=xerror,fmt = 'k-.',linewidth=0.2)
                        

                elif (yvar == 'sampleLAI') : 

                    # check if up 
                    if (dataList[n][xvar+'_up'] != -999 ) :
                    
                        # get up and its error 
                        xup = float(dataList[n][xvar+'_up']) 
                        if (dataList[n][xvar+'_up_err'] != -999 ) :
                            xerrorup = (float(dataList[n][xvar+'_up_err']))**2
                        else :
                             xerrorup = 0.1 * xup
                       
                        # check if also down
                        if (dataList[n][xvar+'_down'] != -999 ) :
                        
                            # also down
                            xdown =  float(dataList[n][xvar+'_down'])  
                            if (dataList[n][xvar+'_down_err'] != -999 ) :
                                xerrordown = (float(dataList[n][xvar+'_down_err']))**2 
                            else :
                                 xerrordown = 0.1 * xdown
                                 
                        # convert to fAPAR and factor in uncertainty of alpha in xerrorup
                        xup = alpha * xup
                        xerrorup = ((alpha * xerrorup)**(2) + (alphaError * xup)**(2))**(0.5)
                        
                    else :
                        # only down 
                        xdown = float(dataList[n][xvar+'_down']) 
                        if (dataList[n][xvar+'_down_err'] != -999 ) :
                            xerror = float(dataList[n][xvar+'_down_err'])**2  
                        else :
                            xerror = 0.1 * xdown 
                    x = alpha * xup + xdown
                    xerror = (max(0,((xup*xerrorup+xdown*xerrordown)/(xup+xdown))))**0.5
                    
                    if ( gain>0) :
                        dasf =  np.array((dataListDASF[n]['sampleDASF'])[2]['data'])

                        
                        if dataList[n]['IGBP_class'] ==  'Evergreen Needleleaf':
                            if (yvar == 'sampleLAI') : 
                                #estDASF = np.exp(0.023505*(np.power(np.log(dasf),2)) + 1.7414*np.log(dasf) + 2.7345)
                                #stdErrorDASF = 14.289*np.power(dasf,2)+4.2901*dasf-0.19569
                                estDASF = np.exp(-0.30661*(np.power(np.log(dasf),2)) + 0.63965*np.log(dasf) + 2.1727)
                                stdErrorDASF = -4.4172*np.power(dasf,2)+19.754*dasf-1.196  
                            elif (yvar == 'samplefAPAR') : 
                                z = np.log(dasf+0.01)-0.01
                                estDASF = -0.0013627*np.power(z,2)+0.22376*z+0.92611+0.2*dasf
                                stdErrorDASF = 0.88147*np.power(dasf,2)-0.5598*dasf+0.17837
                            elif (yvar =='samplefCOVER') :
                                estDASF = np.exp(-0.37245*(np.power(np.log(dasf),2)) + -0.064641*np.log(dasf) + 0.074017)
                                stdErrorDASF = -1.0603*np.power(dasf,2)+1.6887*dasf-0.037161   
                        elif dataList[n]['IGBP_class']== 'Mixed Forest' :
                            # old ones with bad clumping
                            #estDASF = np.exp(-0.0026808*(np.power(np.log(dasf),2)) + 1.4776*np.log(dasf) + 2.2686)
                            #stdErrorDASF = 4.7536*np.power(dasf,2)+4.2083*dasf-0.18081  
                            if (yvar == 'sampleLAI') : 
                                estDASF = np.exp(-0.2668*(np.power(np.log(dasf),2)) + 0.78615*np.log(dasf) + 2.2227)
                                stdErrorDASF = -0.83481*np.power(dasf,2)+8.2123*dasf-0.51067  
                            elif (yvar == 'samplefAPAR') : 
                                z = np.log(dasf+0.01)-0.05
                                estDASF = -0.030564*np.power(z,2)+0.070905*z+0.77337+0.15*dasf
                                stdErrorDASF = 0.65692*np.power(dasf,2)-0.70076*dasf+0.23981
                            elif (yvar == 'samplefCOVER') :
                                estDASF = np.exp(-0.36752*(np.power(np.log(dasf),2)) + -0.036441*np.log(dasf) + 0.077569)
                                stdErrorDASF = -0.94729*np.power(dasf,2)+1.5343*dasf-0.035862 
                        else :
                            if (yvar == 'sampleLAI') : 
                                estDASF = np.exp(-0.39812*(np.power(np.log(dasf),2)) + 0.33646*np.log(dasf) + 2.082)
                                stdErrorDASF = -1.6748*np.power(dasf,2)+16.484*dasf-1.025  
                                #estDASF = np.exp(2.443e-5*(np.power(np.log(dasf),2)) + 1.578*np.log(dasf) + 2.383)
                                #stdErrorDASF = 7.4952*np.power(dasf,2)+4.4447*dasf-0.22168
                            elif (yvar == 'samplefAPAR') : 
                                z = np.log(dasf+0.01)-0.05
                                estDASF = -0.030564*np.power(z,2)+0.070905*z+0.77337+0.15*dasf
                                stdErrorDASF = 0.65692*np.power(dasf,2)-0.70076*dasf+0.23981
                            elif (yvar == 'samplefCOVER') :
                                estDASF = np.exp(-0.41105*(np.power(np.log(dasf),2)) + -0.18412*np.log(dasf) + 0.040711)
                                stdErrorDASF = -1.2707*np.power(dasf,2)+1.9159*dasf-0.040718                                 
                        m1 = est
                        v1 = np.power(stdError,2)
                        m2 = estDASF
                        v2 = np.power(stdErrorDASF,2)/gain
                        est = (m1*v2+m2*v1)/(v1+v2)
                        stdError = (v1*v2)/(v1+v2)
                        
                    # determine residuals for each satellite matchup
                    residual = est-x
                    residualAbs = np.absolute(residual)

                    # only use good matches for stats
                    index = np.where(residualAbs<=np.percentile(residualAbs,percentile))
                    filteredresiduals = residual[index[0]]
                    yerror = stdError[index[0]]/5

                    #print(filteredresiduals)
                    y = x + np.median(filteredresiduals)
                    yerror = np.median(yerror)
                    yerror = ((np.ptp(filteredresiduals)/4/(len(residual)**0.5))**2 +  yerror**2)**0.5 #
                    
                    if (x>0) and (y<5.5)  and (y>0) and ( y < 5.5 ):
                        count = count + 1
                        error[count] = np.median(filteredresiduals)
                        correct[count] = np.absolute(error[count])<np.maximum(0.20*x,0.10)
                        print(n,x,y,dasf)
                        plt.plot(x,y,'o',markersize =symbolSize,markerfacecolor=symbolColour,markeredgecolor='k' )
                        plt.errorbar(x,y,yerr=yerror,xerr=xerror,fmt = 'k-.',linewidth=0.2)

    results = {
        "count": count,
        "MAE": np.median(np.absolute(error)),
        "U" : np.power(np.mean(np.power(error,2)),0.5),
        "A" : np.mean(error),
        "P" : np.power(np.mean(np.power(np.subtract(error,np.mean(error)),2)),0.5),
        "thresh": np.sum(correct)*100/count
    }
    
    return results
#     textstr = '\n'.join((
#         r'$N=%d$' % (count, ),
#         r'$MAE=%.2f$' % (np.median(np.absolute(error)), ),
#         r'$U=%.2f$' % (np.power(np.mean(np.power(error,2)),0.5), ),
#         r'$A=%.2f$' % (np.mean(error), ),
#         r'$P=%.2f$' % (np.power(np.mean(np.power(np.subtract(error,np.mean(error)),2)),0.5), ),
#         r'$THRESH=%.2f$ %%' % (np.mean(correct)*100,)))
    #ax = plt.gca()
    #ax.text(0.015, 0.985, textstr,
     #   horizontalalignment='left',
    #    verticalalignment='top',
     #   transform=ax.transAxes)
    #fig.savefig(fileName, bbox_inches='tight')

# %%
# main function to plot data
# currently hardcodes ratio of LAI/PAI for each IGBP class , need to make this a dictionary
# uncertainties originally given as a range are converted to 1 sigma by dividing range by 4 - implies range if 95%ile coverage of residuals
# uncertainties are combined assuming indpenedence
def plotDataDGBOVFLIGHT(dataListDASF,dataList,xvar,yvar,percentile,fileName,gain,fig):
    laiName = 'LAI_Warren'
    if xvar == laiName :
        plt.plot([0,6],[0,6],'k--')
        plt.ylim(0,6)
        plt.xlim(0,6)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.75*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.75),np.maximum(1.25*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.75),color = 'gray',alpha = 0.1)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.80*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.50),np.maximum(1.20*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.50),color = 'gray',alpha = 0.3)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.85*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.25),np.maximum(1.15*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.25),color = 'gray',alpha = 0.5)
        plt.ylabel('LAI SL2P')
        plt.xlabel('LAI In-Situ')
    elif yvar == 'sampleDASF' :
        plt.plot([0,6],[0,6],'k--')
        plt.ylim(0,1)
        plt.xlim(0,6)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.75*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.75),np.maximum(1.25*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.75),color = 'gray',alpha = 0.1)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.80*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.50),np.maximum(1.20*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.50),color = 'gray',alpha = 0.3)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.85*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.25),np.maximum(1.15*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.25),color = 'gray',alpha = 0.5)
        plt.ylabel(' SL2P')
        plt.xlabel('LAI In-Situ')
    elif xvar == "fcover_Total" : 
        plt.plot([0,1],[0,1],'k--')
        plt.ylim(0,1)
        plt.xlim(0,1)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.8*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.10),np.maximum(1.2*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.10),color = 'gray',alpha = 0.1)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.85*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.075),np.maximum(1.15*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.075),color = 'gray',alpha = 0.3)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.90*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.05),np.maximum(1.10*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.05),color = 'gray',alpha = 0.5)
        plt.ylabel('FCOVER SL2P')
        plt.xlabel('FCOVER In-Situ')
    elif xvar == 'fIPAR' :
        plt.plot([0,1],[0,1],'k--')
        plt.ylim(0,1)
        plt.xlim(0,1)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.8*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.10),np.maximum(1.2*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.10),color = 'gray',alpha = 0.1)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.85*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.075),np.maximum(1.15*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.075),color = 'gray',alpha = 0.3)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.95*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.05),np.maximum(1.05*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.05),color = 'gray',alpha = 0.5)
        plt.ylabel('FAPAR SL2P')
        plt.xlabel('FIPAR In-Situ')
    elif  xvar == 'LAIe_Miller' :
        plt.plot([0,4],[0,4],'k--')
        plt.ylim(0,4)
        plt.xlim(0,4)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.75*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.75),np.maximum(1.25*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.75),color = 'gray',alpha = 0.1)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.80*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.50),np.maximum(1.20*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.50),color = 'gray',alpha = 0.3)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.85*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.25),np.maximum(1.15*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.25),color = 'gray',alpha = 0.5)
        plt.ylabel('LAIe SL2P')
        plt.xlabel('LAIe In-Situ')
    else :
        plt.plot([0,1],[0,1],'k--')
        plt.ylim(0,1)
        plt.xlim(0,1)
        
    error = np.zeros(len(dataList))
    correct = np.zeros(len(dataList)) 
    dasfALL = np.zeros(len(dataList))
    laiALL = np.zeros(len(dataList))    
    count = 0
    for n in range(0,len(dataList)) :
    #for n in range(0,1) :
        
        # check there is satellite data
        if ( (dataList[n][yvar])[2]['data'] ) :

            # get estimate and stdErr
            est = np.array((dataList[n][yvar])[2]['data'])
            stdError = np.array((dataList[n][yvar])[5]['data'])
                        
            # screen in situ data
            if ((dataList[n][xvar+'_down'] != -999 ) or (dataList[n][xvar+'_up'] != -999 )) and ((dataList[n]['up_flag'] == 0 ) and (dataList[n]['down_flag'] == 0 ))  \
                        and ( (dataList[n]['IGBP_class'] == 'Mixed Forest') or (dataList[n]['IGBP_class'] == 'Woody Savannas') or (dataList[n]['IGBP_class'] == 'Deciduous Broadleaf' ) or (dataList[n]['IGBP_class'] == 'Closed Shrublands') ) :
            
                #set symbol size and colour, alpha = LAI/PAI ratio and alphaError=standard error of alpha 
                if (yvar == 'samplefAPAR') :
                    symbolSize = 10
                else :
                    # we use Miller clumping as it averages all zenith angles
                    if ( (dataList[n][xvar+'_up'] != -999 ) and (dataList[n][xvar+'_down'] != -999 )) :
                        clumping = ((dataList[n]['LAI_Miller_up'] * (dataList[n]['clumping_Miller_up']))+ (dataList[n]['clumping_Miller_down'] * (dataList[n]['clumping_Miller_down'])))/(dataList[n]['LAI_Miller_up'] + (dataList[n]['LAI_Miller_down']))
                    elif  (dataList[n][xvar+'_up'] != -999 ) :
                        clumping = dataList[n]['LAI_Miller_up'] 
                    else :
                        clumping = dataList[n]['LAI_Miller_down'] 
                    symbolSize = 20* (1-clumping)   
                    
                if dataList[n]['IGBP_class']== 'Mixed Forest':
                    symbolColour = 'y'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Woody Savannas':
                    symbolColour = 'b'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Evergreen Broadleaf':
                    symbolColour = 'r'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Deciduous Broadleaf':
                    symbolColour = 'r'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Evergreen Needleleaf':
                    symbolColour = 'b'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Deciduous Needleaf':
                    symbolColour = 'b'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Croplands':
                    symbolColour = 'm'       
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Cropland Mosaics':
                    symbolColour = 'm'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Grasslands':
                    symbolColour = 'm'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Grassland':
                    symbolColour = 'm'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Closed Shrublands':
                    symbolColour = 'm'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Open Shrublands':
                    symbolColour = 'm'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Savannas':
                    symbolColour = 'm'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Permanent Wetlands':
                    symbolColour = 'k'
                    alpha = 0.84
                    alphaError = 0.11
                elif dataList[n]['IGBP_class']== 'Tundra':
                    symbolColour = 'k'
                    alpha = 0.84
                    alphaError = 0.11
                else :
                    print(dataList[n]['IGBP_class'])
                    symbolColour = 'g'
                    alpha = 0.84
                    alphaError = 0.11
#                 if dataList[n]['Site'] == 'BartlettExperimentalForest' :
#                     alpha = 0.76 # from https://www.researchgate.net/publication/
#                     symbolColour = 'm'
#                                 # 8688598_Assessing_seasonal_leaf_area_dynamics_and_vertical_leaf_area_distribution_in_eastern_white_pine_Pinus_strobus_L_with_a_portable_light_meter/link/55cdd7ee08ae502646a4c393/download
#                 elif  dataList[n]['Site'] == 'HarvardForest' :
#                     alpha = 0.81 # https://www.sciencedirect.com/science/article/pii/S0168192318302351#sec0055
#                     symbolColour = 'k'
#                 elif dataList[n]['Site'] == 'OakRidge' :
#                     alpha = 0.85 # https://link.springer.com/article/10.1007%2Fs00468-011-0568-4
#                     symbolColour = 'c'
#                 elif dataList[n]['Site'] == 'TalladegaNationalForest':
#                     symbolColour = 'g'
#                     alpha = 0.875 # Sampson et al. 2011
#                 elif dataList[n]['Site'] == 'Underc':
#                     symbolColour = 'aquamarine'
#                     alpha = 0.92  # visual
#                 elif dataList[n]['Site'] == 'SteigerwaldtLandServices':
#                     symbolColour = 'forestgreen'
#                     alpha = 0.875 # Sampson et al. 2011
#                 elif dataList[n]['Site'] == 'OrdwaySwisherBiologicalStation':
#                     symbolColour = 'orange'
#                     alpha = 0.875 # Shrub
                # determine reference value, different for LAI vs fAPAR
                xup = 0
                xerror = 0
                xerrorup = 0
                xerrordown = 0
                
                if (yvar == 'samplefAPAR') :
                
                    # check if up 
                    if (dataList[n]['FIPAR_up'] != -999 ) :
                    
                        # get up and its error 
                        xup = float(dataList[n]['FIPAR_up']) 
                        if (dataList[n]['FIPAR_up_err'] != -999 ) :
                            xerrorup = (float(dataList[n]['FIPAR_up_err']))**2

                       
                        # check if also down
                        if (dataList[n]['FIPAR_down'] != -999 ) :
                        
                            # also down
                            xdown =  ( 1 - xup) * float(dataList[n]['FIPAR_down'])  
                            if (dataList[n]['FIPAR_down_err'] != -999 ) :
                                xerrordown = (float(dataList[n]['FIPAR_down_err']))**2 

                                 
                        # convert to fAPAR and factor in uncertainty of alpha in xerrorup
                        xup = alpha * xup
                        alphaError = 0
                        xerrorup = (xerrorup + (alphaError * xup)**(2))**(0.5)
                        
                    else :
                        # only down 
                        xdown = float(dataList[n]['FIPAR_down']) 
                        if (dataList[n]['FIPAR_down_err'] != -999 ) :
                            xerrordown = float(dataList[n]['FIPAR_down_err'])**2  
                    x = alpha * xup + xdown
                    xerror = (max(0,((xup*xerrorup+xdown*xerrordown)/(xup+xdown))))**0.5
                    if (xerror <= 0 ) :
                        xerror = 0.1 * x
                    if ( gain>0) :
                        dasf =  np.array((dataListDASF[n]['sampleDASF'])[2]['data'])

                        
                    if dataList[n]['IGBP_class'] ==  'Evergreen Needleleaf':
                        z = np.log(dasf+0.01)-0.01
                        estDASF = -0.0013627*np.power(z,2)+0.22376*z+0.92611+0.2*dasf
                        stdErrorDASF = 0.88147*np.power(dasf,2)-0.5598*dasf+0.17837   
                    elif dataList[n]['IGBP_class']== 'Mixed Forest' :
                        z = np.log(dasf+0.01)-0.05
                        estDASF = -0.030564*np.power(z,2)+0.070905*z+0.77337+0.15*dasf
                        stdErrorDASF = 0.65692*np.power(dasf,2)-0.70076*dasf+0.23981
                    else :
                        z = np.log(dasf+0.01)-0.05
                        estDASF = -0.030564*np.power(z,2)+0.070905*z+0.77337+0.15*dasf
                        stdErrorDASF = 0.65692*np.power(dasf,2)-0.70076*dasf+0.23981                                 
                              
#                         m1 = est
#                         v1 = np.power(stdError,2)
#                         m2 = estDASF
#                         v2 = np.power(stdErrorDASF,2)/gain
#                         est = (m1*v2+m2*v1)/(v1+v2)
#                         stdError = (v1*v2)/(v1+v2)
                        est = estDASF;
                        stdError = stdErrorDASF;
                        
                    # determine residuals for each satellite matchup
                    residual = est-x
                    residualAbs = np.absolute(residual)

                    # only use good matches for stats
                    index = np.where(residualAbs<=np.percentile(residualAbs,percentile))
                    filteredresiduals = residual[index[0]]
                    yerror = stdError[index[0]]

                    #print(filteredresiduals)
                    y = x + np.median(filteredresiduals)
                    yerror = np.median(yerror)
                    yerror = ((np.ptp(filteredresiduals)/4/(len(residual)**0.5))**2 +  yerror**2)**0.5 #
                    
                    if (y>0) and ( y < 1 ):
                        count = count + 1
                        error[count] = np.median(filteredresiduals)
                        correct[count] = np.absolute(error[count])<np.maximum(0.20*x,0.10)
                        plt.plot(x,y,symbolColour+'o',markersize =symbolSize,markeredgecolor='k' )
                        plt.errorbar(x,y,yerr=yerror,xerr=xerror,fmt = 'k-.',linewidth=0.2)

                elif (yvar == 'sampleLAI') : 

                    # check if up 
                    if (dataList[n][xvar+'_up'] != -999 ) :
                    
                        # get up and its error 
                        xup = float(dataList[n][xvar+'_up']) 
                        if (dataList[n][xvar+'_up_err'] != -999 ) :
                            xerrorup = (float(dataList[n][xvar+'_up_err']))**2

                       
                        # check if also down
                        if (dataList[n][xvar+'_down'] != -999 ) :
                        
                            # also down
                            xdown =  float(dataList[n][xvar+'_down'])  
                            if (dataList[n][xvar+'_down_err'] != -999 ) :
                                xerrordown = (float(dataList[n][xvar+'_down_err']))**2 

                                 
                        # convert to fAPAR and factor in uncertainty of alpha in xerrorup
                        xup = alpha * xup
                        xerrorup = (xerrorup + (alphaError * xup)**(2))**(0.5)
                        
                    else :
                        # only down 
                        xdown = float(dataList[n][xvar+'_down']) 
                        if (dataList[n][xvar+'_down_err'] != -999 ) :
                            xerror = float(dataList[n][xvar+'_down_err'])**2  

                    x = alpha * xup + xdown
                    xerror = (max(0,((xup*xerrorup+xdown*xerrordown)/(xup+xdown))))**0.5
                    if (xerror <= 0 ) :
                        xerror = 0.1 * x
                        
                    if ( gain>0) :
                        dasf =  np.array((dataListDASF[n]['sampleDASF'])[2]['data'])

                        
                        if dataList[n]['IGBP_class'] ==  'Evergreen Needleleaf':
                            estDASF = 10*np.power(2.0*dasf,2)
                            stdErrorDASF = np.exp(3.152*np.power(dasf,2)+3.5205*dasf-0.026379 )  
                        elif dataList[n]['IGBP_class']== 'Mixed Forest' :
                            estDASF = 10*np.power(1.8*dasf,2)
                            stdErrorDASF =  (np.exp(-48.844*np.power(dasf,3)+76.619*np.power(dasf,2)+-28.619*dasf-3.4263) + np.exp(3.152*np.power(dasf,2)+3.5205*dasf-0.026379 ) )/2
                        else :
                            estDASF = 10*np.power(1.6*dasf,2)
                            stdErrorDASF =  np.exp(-48.844*np.power(dasf,3)+76.619*np.power(dasf,2)+-28.619*dasf-3.4263)
                              
#                         m1 = est
#                         v1 = np.power(stdError,2)
#                         m2 = estDASF
#                         v2 = np.power(stdErrorDASF,2)/gain
#                         est = (m1*v2+m2*v1)/(v1+v2)
#                         stdError = (v1*v2)/(v1+v2)
                        est = estDASF;
                        stdError = stdErrorDASF;
                        
                    # determine residuals for each satellite matchup
                    residual = est-x
                    residualAbs = np.absolute(residual)

                    # only use good matches for stats
                    index = np.where(residualAbs<=np.percentile(residualAbs,percentile))
                    filteredresiduals = residual[index[0]]
                    yerror = stdError[index[0]]

                    #print(filteredresiduals)
                    y = x + np.median(filteredresiduals)
                    yerror = np.median(yerror)
                    yerror = ((np.ptp(filteredresiduals)/4/(len(residual)**0.5))**2 +  yerror**2)**0.5 #
                    
                    if (y>0) and ( y < 5.5 ):
                        count = count + 1
                        error[count] = np.median(filteredresiduals)
                        correct[count] = np.absolute(error[n])<np.maximum(0.20*x,0.10)
                        #print(count,n,dataList[n]['Site'],dataList[n]['IGBP_class'] ,x,y,yerr,xerr,symbolSize,symbolColour)
                        plt.plot(x,y,'o',markersize =symbolSize,markerfacecolor=symbolColour,markeredgecolor='k' )
                        plt.errorbar(x,y,yerr=yerror,xerr=xerror,fmt = 'k-.',linewidth=0.2)

    results = {
        "count": count,
        "MAE": np.median(np.absolute(error)),
        "U" : np.power(np.mean(np.power(error,2)),0.5),
        "A" : np.mean(error),
        "P" : np.power(np.mean(np.power(np.subtract(error,np.mean(error)),2)),0.5),
        "thresh": np.sum(correct)*100/count
    }
    
    return results
#     textstr = '\n'.join((
#         r'$N=%d$' % (count, ),
#         r'$MAE=%.2f$' % (np.median(np.absolute(error)), ),
#         r'$U=%.2f$' % (np.power(np.mean(np.power(error,2)),0.5), ),
#         r'$A=%.2f$' % (np.mean(error), ),
#         r'$P=%.2f$' % (np.power(np.mean(np.power(np.subtract(error,np.mean(error)),2)),0.5), ),
#         r'$THRESH=%.2f$ %%' % (np.mean(correct)*100,)))
    #ax = plt.gca()
    #ax.text(0.015, 0.985, textstr,
     #   horizontalalignment='left',
    #    verticalalignment='top',
     #   transform=ax.transAxes)
    #fig.savefig(fileName, bbox_inches='tight')

# %%
def plotDataDCCRS2(dataListDASF,dataList,xvar,yvar,percentile,fileName,gain,fig):
    laiName = 'PAICEV61'
    if xvar == laiName :
        plt.plot([0,6],[0,6],'k--')
        plt.ylim(0,6)
        plt.xlim(0,6)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.75*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.75),np.maximum(1.25*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.75),color = 'gray',alpha = 0.1)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.80*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.50),np.maximum(1.20*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.50),color = 'gray',alpha = 0.3)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.85*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.25),np.maximum(1.15*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.25),color = 'gray',alpha = 0.5)
        plt.ylabel('LAI SL2P')
        plt.xlabel('LAI In-Situ')
    elif yvar == 'sampleDASF' :
        plt.plot([0,6],[0,6],'k--')
        plt.ylim(0,1)
        plt.xlim(0,6)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.75*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.75),np.maximum(1.25*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.75),color = 'gray',alpha = 0.1)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.80*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.50),np.maximum(1.20*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.50),color = 'gray',alpha = 0.3)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.85*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.25),np.maximum(1.15*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.25),color = 'gray',alpha = 0.5)
        plt.ylabel(' SL2P')
        plt.xlabel('LAI In-Situ')
    elif xvar == "fcover_Total" : 
        plt.plot([0,1],[0,1],'k--')
        plt.ylim(0,1)
        plt.xlim(0,1)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.8*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.10),np.maximum(1.2*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.10),color = 'gray',alpha = 0.1)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.85*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.075),np.maximum(1.15*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.075),color = 'gray',alpha = 0.3)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.90*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.05),np.maximum(1.10*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.05),color = 'gray',alpha = 0.5)
        plt.ylabel('FCOVER SL2P')
        plt.xlabel('FCOVER In-Situ')
    elif xvar == 'Daily_Integrated_Black_Sky_fAPAR' :
        plt.plot([0,1],[0,1],'k--')
        plt.ylim(0,1)
        plt.xlim(0,1)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.8*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.10),np.maximum(1.2*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.10),color = 'gray',alpha = 0.1)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.85*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.075),np.maximum(1.15*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.075),color = 'gray',alpha = 0.3)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.95*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.05),np.maximum(1.05*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.05),color = 'gray',alpha = 0.5)
        plt.ylabel('FAPAR SL2P')
        plt.xlabel('FIPAR In-Situ')
    elif  xvar == 'LAIe_Miller' :
        plt.plot([0,4],[0,4],'k--')
        plt.ylim(0,4)
        plt.xlim(0,4)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.75*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.75),np.maximum(1.25*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.75),color = 'gray',alpha = 0.1)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.80*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.50),np.maximum(1.20*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.50),color = 'gray',alpha = 0.3)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.85*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.25),np.maximum(1.15*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.25),color = 'gray',alpha = 0.5)
        plt.ylabel('LAIe SL2P')
        plt.xlabel('LAIe In-Situ')
    else :
        plt.plot([0,1],[0,1],'k--')
        plt.ylim(0,1)
        plt.xlim(0,1)
        
    error = np.zeros(len(dataList))
    correct = np.zeros(len(dataList)) 
    dasfALL = np.zeros(len(dataList))
    laiALL = np.zeros(len(dataList))    
    count = 0
    for n in range(0,len(dataList)) :

        # check there is satellite data
        if ( (dataList[n][yvar])[2]['data'] )  and ( dataList[n]['PlotID'] != 'TP_plot1_T1_25JUN2019') and ( dataList[n]['PlotID'] != 'PR_plot1_T1_12AUG2019') and ( dataList[n]['PlotID'] != 'TP_plot4_T1_27JUN2019')  and ( dataList[n]['PlotID'] != 'G_C8_L1_R3'): 

            # get estimate and stdErr
            est = np.array((dataList[n][yvar])[2]['data'])/1000
            stdError = np.array((dataList[n][yvar])[5]['data'])/1000
            # screen in situ data
            xvarup = xvar;
            xvardown = xvar;
            if  (yvar == 'samplefAPAR') :
                if 'Daily_Integrated_Black_Sk_yfAPAR_Up' in dataList[n].keys() :
                    xvarup = 'Daily_Integrated_Black_Sk_yfAPAR'
                else :
                    xvarup = 'Daily_Integrated_Black_Sky_fAPAR'
                if 'Daily_Integrated_Black_Sk_yfAPAR_Down' in dataList[n].keys() :
                    xvardown = 'Daily_Integrated_Black_Sk_yfAPAR'
                else :
                    xvardown = 'Daily_Integrated_Black_Sky_fAPAR'     

                    
                # determine reference value, different for LAI vs fAPAR
                xup = 0
                xerror = 0
                
                if (yvar == 'samplefAPAR') :
 
                    if ((dataList[n][xvardown+'_Down'] != -999 ) or (dataList[n][xvarup+'_Up'] != -999 )) :
                        #set symbol size and colour, alpha = LAI/PAI ratio and alphaError=standard error of alpha 
                        # we use Miller clumping as it averages all zenith angles
                        clumping = ((dataList[n]['PAIeCEV61_Up'])+(dataList[n]['PAIeCEV61_Down']))/ (dataList[n]['PAICEV61_Up']+(dataList[n]['PAICEV61_Down']))
                        symbolSize = 20* (1-clumping)      
                        if dataList[n]['NF']== 1:
                            symbolColour = 'r'
                            alpha = 0.76
                            alphaError = 0.11
                        elif dataList[n]['BF']== 1:
                            symbolColour = 'b'
                            alpha = 0.82
                            alphaError = 0.11
                        else :
                            symbolColour = 'y'
                            alpha = 0.82
                            alphaError = 0.11
                    
                    # check if up 
                    if (dataList[n][xvarup+'_Up'] != -999 ) :
                    
                        # get up and its error 
                        xup = float(dataList[n][xvarup+'_Up']) 
                        xerrorup = 0.1 * xup
                       
                        # check if also down
                        if (dataList[n][xvardown+'_Down'] != -999 ) :
                        
                            # also down
                            xdown =  ( 1 - xup) * float(dataList[n][xvardown+'_Down'])  
                            xerrordown = 0.1 * xdown
                                 
                        # convert to fAPAR and factor in uncertainty of alpha in xerrorup
                        xup = alpha * xup
                        xerrorup = (xerrorup + (alphaError * xup)**(2))
                        
                    else :
                        # only down 
                        xdown = float(dataList[n][xvardown+'_Down']) 
                        xerrordown = 0.1 * xdown 
                            
                    x = alpha * xup + xdown
                    xerror = (max(0,((xup*xerrorup+xdown*xerrordown)/(xup+xdown))))**0.5
                    
                    if ( gain>0) :
                        dasf =  np.array((dataListDASF[n]['sampleDASF'])[2]['data'])/1000

                        
                        if dataList[n]['NF']== 1:
                            if (yvar == 'sampleLAI') : 
                                #estDASF = np.exp(0.023505*(np.power(np.log(dasf),2)) + 1.7414*np.log(dasf) + 2.7345)
                                #stdErrorDASF = 14.289*np.power(dasf,2)+4.2901*dasf-0.19569
                                estDASF = np.exp(-0.30661*(np.power(np.log(dasf),2)) + 0.63965*np.log(dasf) + 2.1727)
                                stdErrorDASF = -4.4172*np.power(dasf,2)+19.754*dasf-1.196  
                            elif (yvar == 'samplefAPAR') : 
                                estDASF = np.exp(-0.3766*(np.power(np.log(dasf),2)) + -0.078608*np.log(dasf) + 0.030272)
                                stdErrorDASF = -1.0217*np.power(dasf,2)+1.6158*dasf-0.035258 
                            elif (yvar =='samplefCOVER') :
                                estDASF = np.exp(-0.37245*(np.power(np.log(dasf),2)) + -0.064641*np.log(dasf) + 0.074017)
                                stdErrorDASF = -1.0603*np.power(dasf,2)+1.6887*dasf-0.037161   
                        elif dataList[n]['BF']== 1:   
                            if (yvar == 'sampleLAI') : 
                                estDASF = np.exp(-0.39812*(np.power(np.log(dasf),2)) + 0.33646*np.log(dasf) + 2.082)
                                stdErrorDASF = -1.6748*np.power(dasf,2)+16.484*dasf-1.025  
                                #estDASF = np.exp(2.443e-5*(np.power(np.log(dasf),2)) + 1.578*np.log(dasf) + 2.383)
                                #stdErrorDASF = 7.4952*np.power(dasf,2)+4.4447*dasf-0.22168
                            elif (yvar == 'samplefAPAR') : 
                                estDASF = np.exp(-0.41655*(np.power(np.log(dasf),2)) + 0.20354*np.log(dasf) + 0.007866)
                                stdErrorDASF = -1.2278*np.power(dasf,2)+1.8353*dasf-0.038342 
                            elif (yvar == 'samplefCOVER') :
                                estDASF = np.exp(-0.41105*(np.power(np.log(dasf),2)) + -0.18412*np.log(dasf) + 0.040711)
                                stdErrorDASF = -1.2707*np.power(dasf,2)+1.9159*dasf-0.040718              
                        else :
                            # old ones with bad clumping
                            #estDASF = np.exp(-0.0026808*(np.power(np.log(dasf),2)) + 1.4776*np.log(dasf) + 2.2686)
                            #stdErrorDASF = 4.7536*np.power(dasf,2)+4.2083*dasf-0.18081  
                            if (yvar == 'sampleLAI') : 
                                estDASF = np.exp(-0.2668*(np.power(np.log(dasf),2)) + 0.78615*np.log(dasf) + 2.2227)
                                stdErrorDASF = -0.83481*np.power(dasf,2)+8.2123*dasf-0.51067  
                            elif (yvar == 'samplefAPAR') : 
                                estDASF = np.exp(-0.37061*(np.power(np.log(dasf),2)) + -0.047058*np.log(dasf) + 0.036232)
                                stdErrorDASF = -0.91062*np.power(dasf,2)+1.4666*dasf-0.03405 
                            elif (yvar == 'samplefCOVER') :
                                estDASF = np.exp(-0.36752*(np.power(np.log(dasf),2)) + -0.036441*np.log(dasf) + 0.077569)
                                stdErrorDASF = -0.94729*np.power(dasf,2)+1.5343*dasf-0.035862                               
                        #m1 = est
                        #v1 = np.power(stdError,2)
                        #m2 = estDASF
                        #v2 = np.power(stdErrorDASF,2)/gain
                        #est = (m1*v2+m2*v1)/(v1+v2)
                        #stdError = (v1*v2)/(v1+v2)
                        est = estDASF
                        stdError = stdErrorDASF
                        
                    # determine residuals for each satellite matchup
                    residual = est-x
                    residualAbs = np.absolute(residual)

                    # only use good matches for stats
                    index = np.where(residualAbs<=np.percentile(residualAbs,percentile))
                    filteredresiduals = residual[index[0]]
                    yerror = stdError[index[0]]

                    #print(filteredresiduals)
                    error[n] = np.median(filteredresiduals)
                    y = x + np.median(filteredresiduals)
                    yerror = np.median(yerror)
                    yerror = ((np.ptp(filteredresiduals)/4/(len(residual)**0.5))**2 +  yerror**2)**0.5 #
                    
                    if (y>0) and ( y < 1 ):
                        count = count + 1
                        correct[count] = np.absolute(error[n])<np.maximum(0.20*x,0.10)
                        plt.plot(x,y,symbolColour+'o',markersize =10,markeredgecolor='k' )
                        plt.errorbar(x,y,yerr=yerror,xerr=xerror,fmt = 'k-.',linewidth=0.2)

            elif (yvar == 'sampleLAI') : 
                    
                if ((dataList[n][xvardown+'_Down'] != -999 ) or (dataList[n][xvarup+'_Up'] != -999 )) :
                    #set symbol size and colour, alpha = LAI/PAI ratio and alphaError=standard error of alpha 
                    # we use Miller clumping as it averages all zenith angles
                    clumping = ((dataList[n]['PAIeCEV61_Up'])+(dataList[n]['PAIeCEV61_Down']))/ (dataList[n]['PAICEV61_Up']+(dataList[n]['PAICEV61_Down']))
                    symbolSize = 20* (1-clumping)      
                    if dataList[n]['NF']== 1:
                        symbolColour = 'r'
                        alpha = 0.85
                        alphaError = 0.11
                    elif dataList[n]['BF']== 1:
                        symbolColour = 'b'
                        alpha = 0.9
                        alphaError = 0.11
                    else :
                        symbolColour = 'y'
                        alpha = 1
                        alphaError = 0.11

                # check if up 
                if (dataList[n][xvarup+'_Up'] != -999 ) :

                    # get up and its error 
                    xup = float(dataList[n][xvarup+'_Up']) 
                    xerrorup = 0.1 * xup

                    # check if also down
                    if (dataList[n][xvardown+'_Down'] != -999 ) :

                        # also down
                        xdown =  float(dataList[n][xvardown+'_Down'])  
                        xerrordown = 0.1 * xdown

                    # convert to fAPAR and factor in uncertainty of alpha in xerrorup
                    xup = alpha * xup
                    xerrorup = ((alpha * xerrorup)**(2) + (alphaError * xup)**(2))**(0.5)

                else :
                    # only down 
                    xdown = float(dataList[n][xvardown+'_Down']) 
                    xerrordown = 0.1 * xdown 

                x = alpha * xup + xdown
                xerror = (max(0,((xup*xerrorup+xdown*xerrordown)/(xup+xdown))))**0.5


                dasf =  np.array((dataListDASF[n]['sampleDASF'])[2]['data'])
                if dataList[n]['NF']== 1:
                    if (yvar == 'sampleLAI') : 
                        #estDASF = np.exp(0.023505*(np.power(np.log(dasf),2)) + 1.7414*np.log(dasf) + 2.7345)
                        #stdErrorDASF = 14.289*np.power(dasf,2)+4.2901*dasf-0.19569
                        estDASF = np.exp(-0.30661*(np.power(np.log(dasf),2)) + 0.63965*np.log(dasf) + 2.1727)
                        stdErrorDASF = -4.4172*np.power(dasf,2)+19.754*dasf-1.196  
                    elif (yvar == 'samplefAPAR') : 
                        estDASF = np.exp(-0.3766*(np.power(np.log(dasf),2)) + -0.078608*np.log(dasf) + 0.030272)
                        stdErrorDASF = -1.0217*np.power(dasf,2)+1.6158*dasf-0.035258 
                    elif (yvar =='samplefCOVER') :
                        estDASF = np.exp(-0.37245*(np.power(np.log(dasf),2)) + -0.064641*np.log(dasf) + 0.074017)
                        stdErrorDASF = -1.0603*np.power(dasf,2)+1.6887*dasf-0.037161   
                elif dataList[n]['BF']== 1:   
                    if (yvar == 'sampleLAI') : 
                        estDASF = np.exp(-0.39812*(np.power(np.log(dasf),2)) + 0.33646*np.log(dasf) + 2.082)
                        stdErrorDASF = -1.6748*np.power(dasf,2)+16.484*dasf-1.025  
                        #estDASF = np.exp(2.443e-5*(np.power(np.log(dasf),2)) + 1.578*np.log(dasf) + 2.383)
                        #stdErrorDASF = 7.4952*np.power(dasf,2)+4.4447*dasf-0.22168
                    elif (yvar == 'samplefAPAR') : 
                        estDASF = np.exp(-0.41655*(np.power(np.log(dasf),2)) + 0.20354*np.log(dasf) + 0.007866)
                        stdErrorDASF = -1.2278*np.power(dasf,2)+1.8353*dasf-0.038342 
                    elif (yvar == 'samplefCOVER') :
                        estDASF = np.exp(-0.41105*(np.power(np.log(dasf),2)) + -0.18412*np.log(dasf) + 0.040711)
                        stdErrorDASF = -1.2707*np.power(dasf,2)+1.9159*dasf-0.040718              
                else :
                    # old ones with bad clumping
                    #estDASF = np.exp(-0.0026808*(np.power(np.log(dasf),2)) + 1.4776*np.log(dasf) + 2.2686)
                    #stdErrorDASF = 4.7536*np.power(dasf,2)+4.2083*dasf-0.18081  
                    if (yvar == 'sampleLAI') : 
                        estDASF = np.exp(-0.2668*(np.power(np.log(dasf),2)) + 0.78615*np.log(dasf) + 2.2227)
                        stdErrorDASF = -0.83481*np.power(dasf,2)+8.2123*dasf-0.51067  
                    elif (yvar == 'samplefAPAR') : 
                        estDASF = np.exp(-0.37061*(np.power(np.log(dasf),2)) + -0.047058*np.log(dasf) + 0.036232)
                        stdErrorDASF = -0.91062*np.power(dasf,2)+1.4666*dasf-0.03405 
                    elif (yvar == 'samplefCOVER') :
                        estDASF = np.exp(-0.36752*(np.power(np.log(dasf),2)) + -0.036441*np.log(dasf) + 0.077569)
                        stdErrorDASF = -0.94729*np.power(dasf,2)+1.5343*dasf-0.035862                                 
                #if dataList[n]['NF']== 1:
                #    estDASF = np.exp(0.023505*(np.power(np.log(dasf),2)) + 1.7414*np.log(dasf) + 2.7345)
                #    stdErrorDASF = 14.289*np.power(dasf,2)+4.2901*dasf-0.19569
                #elif dataList[n]['BF']== 1:   
                #    estDASF = np.exp(2.443e-5*(np.power(np.log(dasf),2)) + 1.578*np.log(dasf) + 2.383)
                #    stdErrorDASF = 7.4952*np.power(dasf,2)+4.4447*dasf-0.22168
                #else :
                #    estDASF = np.exp(-0.0026808*(np.power(np.log(dasf),2)) + 1.4776*np.log(dasf) + 2.2686)
                #    stdErrorDASF = 4.7536*np.power(dasf,2)+4.2083*dasf-0.18081  


                if ( gain>0) :
                    m1 = est
                    v1 = np.power(stdError,2)
                    m2 = estDASF
                    v2 = np.power(np.maximum(0.1*estDASF,stdErrorDASF),2)/gain
                    est = (m1*v2+m2*v1)/(v1+v2)
                    stdError = (v1*v2)/(v1+v2)

                # determine residuals for each satellite matchup
                residual = est-x
                residualAbs = np.absolute(residual)

                # only use good matches for stats
                index = np.where(residualAbs<=np.percentile(residualAbs,percentile))
                filteredresiduals = residual[index[0]]
                yerror = stdError[index[0]]

                #print(filteredresiduals)
                y = x + np.median(filteredresiduals)
                yerror = np.median(yerror)
                yerror = ((np.ptp(filteredresiduals)/4/(len(residual)**0.5))**2 +  yerror**2)**0.5 #

                if (y>0) and ( y < 5.5 ):
                    count = count + 1
                    error[count] = np.median(filteredresiduals)
                    correct[count] = np.absolute(error[count])<np.maximum(0.20*x,0.10)
                    plt.plot(x,y,symbolColour+'o',markersize =symbolSize,markeredgecolor='k' )
                    plt.errorbar(x,y,yerr=yerror,xerr=xerror,fmt = 'k-.',linewidth=0.2)

    
    results = {
        "count": count,
        "MAE": np.median(np.absolute(error)),
        "U" : np.power(np.mean(np.power(error,2)),0.5),
        "A" : np.mean(error),
        "P" : np.power(np.mean(np.power(np.subtract(error,np.mean(error)),2)),0.5),
        "thresh": np.sum(correct)*100/count
    }
    
    return results
#     textstr = '\n'.join((
#         r'$N=%d$' % (count, ),
#         r'$MAE=%.2f$' % (np.median(np.absolute(error)), ),
#         r'$U=%.2f$' % (np.power(np.mean(np.power(error,2)),0.5), ),
#         r'$A=%.2f$' % (np.mean(error), ),
#         r'$P=%.2f$' % (np.power(np.mean(np.power(np.subtract(error,np.mean(error)),2)),0.5), ),
#         "thresh": np.sum(correct)*100/count
    #ax = plt.gca()
    #ax.text(0.015, 0.985, textstr,
     #   horizontalalignment='left',
    #    verticalalignment='top',
     #   transform=ax.transAxes)
    #fig.savefig(fileName, bbox_inches='tight')

# %%
def plotDataDCCRS2FLIGHT(dataListDASF,dataList,xvar,yvar,percentile,fileName,gain,fig):
    laiName = 'PAICEV61'
    if xvar == laiName :
        plt.plot([0,6],[0,6],'k--')
        plt.ylim(0,6)
        plt.xlim(0,6)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.75*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.75),np.maximum(1.25*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.75),color = 'gray',alpha = 0.1)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.80*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.50),np.maximum(1.20*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.50),color = 'gray',alpha = 0.3)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.85*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.25),np.maximum(1.15*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.25),color = 'gray',alpha = 0.5)
        plt.ylabel('LAI SL2P')
        plt.xlabel('LAI In-Situ')
    elif yvar == 'sampleDASF' :
        plt.plot([0,6],[0,6],'k--')
        plt.ylim(0,1)
        plt.xlim(0,6)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.75*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.75),np.maximum(1.25*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.75),color = 'gray',alpha = 0.1)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.80*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.50),np.maximum(1.20*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.50),color = 'gray',alpha = 0.3)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.85*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.25),np.maximum(1.15*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.25),color = 'gray',alpha = 0.5)
        plt.ylabel(' SL2P')
        plt.xlabel('LAI In-Situ')
    elif xvar == "fcover_Total" : 
        plt.plot([0,1],[0,1],'k--')
        plt.ylim(0,1)
        plt.xlim(0,1)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.8*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.10),np.maximum(1.2*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.10),color = 'gray',alpha = 0.1)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.85*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.075),np.maximum(1.15*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.075),color = 'gray',alpha = 0.3)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.90*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.05),np.maximum(1.10*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.05),color = 'gray',alpha = 0.5)
        plt.ylabel('FCOVER SL2P')
        plt.xlabel('FCOVER In-Situ')
    elif xvar == 'fIPAR' :
        plt.plot([0,1],[0,1],'k--')
        plt.ylim(0,1)
        plt.xlim(0,1)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.8*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.10),np.maximum(1.2*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.10),color = 'gray',alpha = 0.1)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.85*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.075),np.maximum(1.15*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.075),color = 'gray',alpha = 0.3)
        plt.fill_between(np.arange(0,1,0.01) ,np.minimum(0.95*np.arange(0,1,0.01),np.arange(0,1,0.01)-0.05),np.maximum(1.05*np.arange(0,1,0.01),np.arange(0,1,0.01)+0.05),color = 'gray',alpha = 0.5)
        plt.ylabel('FAPAR SL2P')
        plt.xlabel('FIPAR In-Situ')
    elif  xvar == 'LAIe_Miller' :
        plt.plot([0,4],[0,4],'k--')
        plt.ylim(0,4)
        plt.xlim(0,4)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.75*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.75),np.maximum(1.25*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.75),color = 'gray',alpha = 0.1)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.80*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.50),np.maximum(1.20*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.50),color = 'gray',alpha = 0.3)
        plt.fill_between(np.arange(0,6,0.1) ,np.minimum(0.85*np.arange(0,6,0.1),np.arange(0,6,0.1)-0.25),np.maximum(1.15*np.arange(0,6,0.1),np.arange(0,6,0.1)+0.25),color = 'gray',alpha = 0.5)
        plt.ylabel('LAIe SL2P')
        plt.xlabel('LAIe In-Situ')
    else :
        plt.plot([0,1],[0,1],'k--')
        plt.ylim(0,1)
        plt.xlim(0,1)
        
    error = np.zeros(len(dataList))
    correct = np.zeros(len(dataList)) 
    dasfALL = np.zeros(len(dataList))
    laiALL = np.zeros(len(dataList))    
    count = 0
    for n in range(0,len(dataList)) :

        # check there is satellite data
        if ( (dataList[n][yvar])[2]['data'] )  and ( dataList[n]['PlotID'] != 'TP_plot1_T1_25JUN2019') and ( dataList[n]['PlotID'] != 'PR_plot1_T1_12AUG2019') and ( dataList[n]['PlotID'] != 'TP_plot4_T1_27JUN2019')  and ( dataList[n]['PlotID'] != 'G_C8_L1_R3'): 

            # get estimate and stdErr
            est = np.array((dataList[n][yvar])[2]['data'])/1000
            stdError = np.array((dataList[n][yvar])[5]['data'])/1000
            # screen in situ data
            xup = 0
            xerror = 0
                
            if  (yvar == 'samplefAPAR') :
                if 'Daily_Integrated_Black_Sk_yfAPAR_Up' in dataList[n].keys() :
                    xvarup = 'Daily_Integrated_Black_Sk_yfAPAR'
                else :
                    xvarup = 'Daily_Integrated_Black_Sky_fAPAR'
                if 'Daily_Integrated_Black_Sk_yfAPAR_Down' in dataList[n].keys() :
                    xvardown = 'Daily_Integrated_Black_Sk_yfAPAR'
                else :
                    xvardown = 'Daily_Integrated_Black_Sky_fAPAR'     

 
                if ((dataList[n][xvardown+'_Down'] != -999 ) or (dataList[n][xvarup+'_Up'] != -999 )) :
                    #set symbol size and colour, alpha = LAI/PAI ratio and alphaError=standard error of alpha 
                    # we use Miller clumping as it averages all zenith angles
                    clumping = ((dataList[n]['PAIeCEV61_Up'])+(dataList[n]['PAIeCEV61_Down']))/ (dataList[n]['PAICEV61_Up']+(dataList[n]['PAICEV61_Down']))
                    symbolSize = 20* (1-clumping)      
                    if dataList[n]['NF']== 1:
                        symbolColour = 'r'
                        alpha = 0.76
                        alphaError = 0.11
                    elif dataList[n]['BF']== 1:
                        symbolColour = 'b'
                        alpha = 0.82
                        alphaError = 0.11
                    else :
                        symbolColour = 'y'
                        alpha = 0.82
                        alphaError = 0.11

                # check if up 
                if (dataList[n][xvarup+'_Up'] != -999 ) :

                    # get up and its error 
                    xup = float(dataList[n][xvarup+'_Up']) 
                    xerrorup = 0.1 * xup

                    # check if also down
                    if (dataList[n][xvardown+'_Down'] != -999 ) :

                        # also down
                        xdown =  ( 1 - xup) * float(dataList[n][xvardown+'_Down'])  
                        xerrordown = 0.1 * xdown

                    # convert to fAPAR and factor in uncertainty of alpha in xerrorup
                    xup = alpha * xup
                    xerrorup = (xerrorup + (alphaError * xup)**(2))

                else :
                    # only down 
                    xdown = float(dataList[n][xvardown+'_Down']) 
                    xerrordown = 0.1 * xdown 

                x = alpha * xup + xdown
                xerror = (max(0,((xup*xerrorup+xdown*xerrordown)/(xup+xdown))))**0.5
                

                if ( gain>0) :
                    dasf =  np.array((dataListDASF[n]['sampleDASF'])[2]['data'])/1000
                    #print(n,dasf)
                    if dataList[n]['NF']== 1:
                        z = np.log(dasf+0.01)-0.01
                        estDASF = -0.0013627*np.power(z,2)+0.22376*z+0.92611+0.2*dasf-0.1
                        stdErrorDASF = 0.88147*np.power(dasf,2)-0.5598*dasf+0.17837
                    elif dataList[n]['BF']== 1:   
                        z = np.log(dasf+0.01)-0.05
                        estDASF = -0.030564*np.power(z,2)+0.070905*z+0.77337+0.15*dasf-0.1
                        stdErrorDASF = 0.65692*np.power(dasf,2)-0.70076*dasf+0.23981           
                    else :
                        z = np.log(dasf+0.01)-0.05
                        estDASF = -0.030564*np.power(z,2)+0.070905*z+0.77337+0.15*dasf-0.1
                        stdErrorDASF = 0.65692*np.power(dasf,2)-0.70076*dasf+0.23981


                    m1 = est
                    v1 = np.power(stdError,2)
                    m2 = estDASF
                    v2 = np.power(stdErrorDASF,2)/gain
                    est = (m1*v2+m2*v1)/(v1+v2)
                    stdError = (v1*v2)/(v1+v2)
                    
                    
                # determine residuals for each satellite matchup
                residual = est-x
                residualAbs = np.absolute(residual)

                # only use good matches for stats
                index = np.where(residualAbs<=np.percentile(residualAbs,percentile))
                filteredresiduals = residual[index[0]]
                yerror = stdError[index[0]]

                #print(filteredresiduals)
                error[n] = np.median(filteredresiduals)
                y = x + np.median(filteredresiduals)
                yerror = np.median(yerror)
                yerror = ((np.ptp(filteredresiduals)/4/(len(residual)**0.5))**2 +  yerror**2)**0.5 #

                if (y>0) and ( y < 1 ):
                    count = count + 1
                    correct[count] = np.absolute(error[count])<np.maximum(0.20*x,0.10)
                    plt.plot(x,y,symbolColour+'o',markersize =symbolSize,markeredgecolor='k' )
                    plt.errorbar(x,y,yerr=yerror,xerr=xerror,fmt = 'k-.',linewidth=0.2)

            elif (yvar == 'sampleLAI') : 

                if ((dataList[n][xvar+'_Down'] != -999 ) or (dataList[n][xvar+'_Up'] != -999 )) :
                    #set symbol size and colour, alpha = LAI/PAI ratio and alphaError=standard error of alpha 
                    # we use Miller clumping as it averages all zenith angles
                    clumping = ((dataList[n]['PAIeCEV61_Up'])+(dataList[n]['PAIeCEV61_Down']))/ (dataList[n]['PAICEV61_Up']+(dataList[n]['PAICEV61_Down']))
                    symbolSize = 20* (1-clumping)      
                    if dataList[n]['NF']== 1:
                        symbolColour = 'r'
                        alpha = 0.85
                        alphaError = 0.11
                    elif dataList[n]['BF']== 1:
                        symbolColour = 'b'
                        alpha = 0.9
                        alphaError = 0.11
                    else :
                        symbolColour = 'y'
                        alpha = 1
                        alphaError = 0.11

                # check if up 
                if (dataList[n][xvar+'_Up'] != -999 ) :

                    # get up and its error 
                    xup = float(dataList[n][xvar+'_Up']) 
                    xerrorup = 0.1 * xup

                    # check if also down
                    if (dataList[n][xvar+'_Down'] != -999 ) :

                        # also down
                        xdown =  float(dataList[n][xvar+'_Down'])  
                        xerrordown = 0.1 * xdown

                    # convert to fAPAR and factor in uncertainty of alpha in xerrorup
                    xup = alpha * xup
                    xerrorup = (xerrorup + (alphaError * xup)**(2))**(0.5)

                else :
                    # only down 
                    xdown = float(dataList[n][xvar+'_Down']) 
                    xerrordown = 0.1 * xdown 

                x = alpha * xup + xdown
                xerror = (max(0,((xup*xerrorup+xdown*xerrordown)/(xup+xdown))))**0.5

                if ( gain>0) :
                    dasf =  np.array((dataListDASF[n]['sampleDASF'])[2]['data'])/1000
                    #print(n,dasf)
                    if dataList[n]['NF']== 1:
                            #estDASF = np.exp(0.023505*(np.power(np.log(dasf),2)) + 1.7414*np.log(dasf) + 2.7345)
                            #stdErrorDASF = 14.289*np.power(dasf,2)+4.2901*dasf-0.19569
                            estDASF = 10*np.power(1.6*dasf,2)
                            stdErrorDASF = np.exp(3.152*np.power(dasf,2)+3.5205*dasf-0.026379 ) 
                    elif dataList[n]['BF']== 1:   
                        estDASF = 10*np.power(1.6*dasf,2)
                        stdErrorDASF =  np.exp(-48.844*np.power(dasf,3)+76.619*np.power(dasf,2)+-28.619*dasf-3.4263)
                        #estDASF = np.exp(2.443e-5*(np.power(np.log(dasf),2)) + 1.578*np.log(dasf) + 2.383)
                        #stdErrorDASF = 7.4952*np.power(dasf,2)+4.4447*dasf-0.22168           
                    else : 
                        estDASF = 10*np.power(1.6*dasf,2)
                        stdErrorDASF =  (np.exp(-48.844*np.power(dasf,3)+76.619*np.power(dasf,2)+-28.619*dasf-3.4263) + np.exp(3.152*np.power(dasf,2)+3.5205*dasf-0.026379 ) )/2
        

                    m1 = est
                    v1 = np.power(stdError,2)
                    m2 = estDASF
                    v2 = np.power(stdErrorDASF,2)/gain
                    est = (m1*v2+m2*v1)/(v1+v2)
                    stdError = (v1*v2)/(v1+v2)


                # determine residuals for each satellite matchup
                residual = est-x
                residualAbs = np.absolute(residual)

                # only use good matches for stats
                index = np.where(residualAbs<=np.percentile(residualAbs,percentile))
                filteredresiduals = residual[index[0]]
                yerror = stdError[index[0]]

                #print(filteredresiduals)
                y = x + np.median(filteredresiduals)
                yerror = np.median(yerror)
                yerror = ((np.ptp(filteredresiduals)/4/(len(residual)**0.5))**2 +  yerror**2)**0.5 #

                if (y>0) and ( y < 5.5 ):
                    count = count + 1
                    error[count] = np.median(filteredresiduals)
                    correct[count] = np.absolute(error[count])<np.maximum(0.20*x,0.10)
                    plt.plot(x,y,symbolColour+'o',markersize =symbolSize,markeredgecolor='k' )
                    plt.errorbar(x,y,yerr=yerror,xerr=xerror,fmt = 'k-.',linewidth=0.2)

    
    results = {
        "count": count,
        "MAE": np.median(np.absolute(error)),
        "U" : np.power(np.mean(np.power(error,2)),0.5),
        "A" : np.mean(error),
        "P" : np.power(np.mean(np.power(np.subtract(error,np.mean(error)),2)),0.5),
        "thresh": np.sum(correct)*100/count
    }
    
    return results
#     textstr = '\n'.join((
#         r'$N=%d$' % (count, ),
#         r'$MAE=%.2f$' % (np.median(np.absolute(error)), ),
#         r'$U=%.2f$' % (np.power(np.mean(np.power(error,2)),0.5), ),
#         r'$A=%.2f$' % (np.mean(error), ),
#         r'$P=%.2f$' % (np.power(np.mean(np.power(np.subtract(error,np.mean(error)),2)),0.5), ),
#         r'$THRESH=%.2f$ %%' % (np.mean(correct)*100,)))
    #ax = plt.gca()
    #ax.text(0.015, 0.985, textstr,
     #   horizontalalignment='left',
    #    verticalalignment='top',
     #   transform=ax.transAxes)
    #fig.savefig(fileName, bbox_inches='tight')

# %%
import pickle
with open("E:/wp3/Validation/LAIGBOV.txt", "rb") as fp:   #Pickling
    GBOVDataLAISL2P = pickle.load(fp)
with open("E:/wp3/Validation/fAPARGBOV.txt", "rb") as fp:   #Pickling
    GBOVDatafAPARSL2P = pickle.load(fp)
with open("E:/wp3/Validation/data_GBOV_RM6_20210313_LAI_SL2PCCRS_v3.txt", "rb") as fp:   #Pickling
    GBOVDataLAICCRS = pickle.load(fp)
with open("E:/wp3/Validation/data_GBOV_RM6_20210313_fAPAR_SL2PCCRS_v3.txt", "rb") as fp:   #Pickling
    GBOVDatafAPARCCRS = pickle.load(fp)
with open("E:/wp3/Validation/data_GBOV_RM6_20210313_DASF_SL2PCCRS_v3.txt", "rb") as fp:   #Pickling
    GBOVDataDASFCCRS = pickle.load(fp)

# %%
import pickle
with open("E:/wp3/Validation/LAI.txt", "rb") as fp:   #Pickling
    ccrsDataLAISL2P = pickle.load(fp)
with open("E:/wp3/Validation/fAPAR.txt", "rb") as fp:   #Pickling
    ccrsDatafAPARSL2P = pickle.load(fp)
with open("E:/wp3/Validation/fCOVER.txt", "rb") as fp:   #Pickling
    ccrsDatafCOVERSL2P = pickle.load(fp)
    
with open("E:/wp3/Validation/LAICCRS.txt", "rb") as fp:   #Pickling
    ccrsDataLAICCRS = pickle.load(fp)
with open("E:/wp3/Validation/fAPARCCRS.txt", "rb") as fp:   #Pickling
    ccrsDatafAPARCCRS = pickle.load(fp)
with open("E:/wp3/Validation/fCOVERCCRS.txt", "rb") as fp:   #Pickling
    ccrsDatafCOVERCCRS = pickle.load(fp)
with open("E:/wp3/Validation/DASFCCRS.txt", "rb") as fp:   #Pickling
    ccrsDataDASFCCRS = pickle.load(fp)

# %%
with open("E:/wp3/Validation/LAICCRSFLIGHT.txt", "rb") as fp:   #Pickling
    ccrsDataLAIFLIGHT = pickle.load(fp)
with open("E:/wp3/Validation/fAPARCCRSFLIGHT.txt", "rb") as fp:   #Pickling
    ccrsDatafAPARFLIGHT = pickle.load(fp)
with open("E:/wp3/Validation/fCOVERCCRSFLIGHT.txt", "rb") as fp:   #Pickling
    ccrsDatafCOVERFLIGHT = pickle.load(fp)
with open("E:/wp3/Validation/DASFCCRSFLIGHT.txt", "rb") as fp:   #Pickling
    ccrsDataDASFFLIGHT = pickle.load(fp)

# %%
with open("E:/wp3/Validation/data_GBOV_RM6_20210313_LAI_SL2PFLIGHT_v2.txt", "rb") as fp:   #Pickling
    GBOVDataLAIFLIGHT = pickle.load(fp)
with open("E:/wp3/Validation/data_GBOV_RM6_20210313_fAPAR_SL2FLIGHT_v2.txt", "rb") as fp:   #Pickling
    GBOVDatafAPARFLIGHT = pickle.load(fp)
with open("E:/wp3/Validation/data_GBOV_RM6_20210313_DASF_SL2PFLIGHT_v2.txt", "rb") as fp:   #Pickling
    GBOVDataSL2PFLIGHT = pickle.load(fp)

# %%
fig = plt.figure();
r1 = plotDataDGBOV(GBOVDataDASFCCRS,GBOVDataLAISL2P,'LAI_Warren','sampleLAI',50,'E:\wp3\Validation\LAIGBOV.png',0,fig)
r2 = plotDataDCCRS2(ccrsDataDASFCCRS,ccrsDataLAISL2P,'PAICEV61','sampleLAI',50,'E:\wp3\Validation\LAIGBOV.png',0,fig)
ax = plt.gca()
n = r1['count'] + r2['count']
textstr = '\n'.join(( 
    r'$N=%d$' % n, 
    r'$MAE=%.2f$' % ((r1['count']*r1['MAE']+r1['count']*r2['MAE'])/n, ), 
    r'$U=%.2f$' % ((r1['count']*r1['U']+r1['count']*r2['MAE'])/n, ), 
    r'$A=%.2f$' % ((r1['count']*r1['A']+r1['count']*r2['MAE'])/n, ), 
    r'$P=%.2f$' % ((r1['count']*r1['P']+r1['count']*r2['MAE'])/n, ), 
    r'$THRESH=%.2f$%%' % ((r1['count']*r1['thresh']+r1['thresh']*r2['MAE'])/n, )))
ax.text(0.015, 0.985, textstr,horizontalalignment='left',verticalalignment='top',transform=ax.transAxes)
fig.savefig('E:\wp3\Validation\LAISL2P.png', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1296-e35abc02d0e0> in <module>
#       1 fig = plt.figure();
# ----> 2 r1 = plotDataDGBOV(GBOVDataDASFCCRS,GBOVDataLAISL2P,'LAI_Warren','sampleLAI',50,'E:\wp3\Validation\LAIGBOV.png',0,fig)
#       3 r2 = plotDataDCCRS2(ccrsDataDASFCCRS,ccrsDataLAISL2P,'PAICEV61','sampleLAI',50,'E:\wp3\Validation\LAIGBOV.png',0,fig)
#       4 ax = plt.gca()
#       5 n = r1['count'] + r2['count']
#
# <ipython-input-1287-d36af9cb9cdb> in plotDataDGBOV(dataListDASF, dataList, xvar, yvar, percentile, fileName, gain, fig)
#     396                         error[count] = np.median(filteredresiduals)
#     397                         correct[count] = np.absolute(error[count])<np.maximum(0.20*x,0.10)
# --> 398                         print(n,x,y,dasf)
#     399                         plt.plot(x,y,'o',markersize =symbolSize,markerfacecolor=symbolColour,markeredgecolor='k' )
#     400                         plt.errorbar(x,y,yerr=yerror,xerr=xerror,fmt = 'k-.',linewidth=0.2)
#
# UnboundLocalError: local variable 'dasf' referenced before assignment

# %%
fig = plt.figure();
r1 = plotDataDGBOV(GBOVDataDASFCCRS,GBOVDataLAICCRS,'LAI_Warren','sampleLAI',50,'E:\wp3\Validation\LAIGBOV.png',0,fig)
r2 = plotDataDCCRS2(ccrsDataDASFCCRS,ccrsDataLAICCRS,'PAICEV61','sampleLAI',50,'E:\wp3\Validation\LAIGBOV.png',0,fig)
#r1 = plotDataDGBOVFLIGHT(GBOVDataDASFCCRS,GBOVDataLAIFLIGHT,'LAI_Warren','sampleLAI',50,'E:\wp3\Validation\LAIGBOV.png',1000,fig)
#r2 = plotDataDCCRS2FLIGHT(ccrsDataDASFCCRS,ccrsDataLAIFLIGHT,'PAICEV61','sampleLAI',50,'E:\wp3\Validation\LAIGBOV.png',1000,fig)

ax = plt.gca()
n = r1['count'] + r2['count']
textstr = '\n'.join(( 
    r'$N=%d$' % n, 
    r'$MAE=%.2f$' % ((r1['count']*r1['MAE']+r1['count']*r2['MAE'])/n, ), 
    r'$U=%.2f$' % ((r1['count']*r1['U']+r1['count']*r2['MAE'])/n, ), 
    r'$A=%.2f$' % ((r1['count']*r1['A']+r1['count']*r2['MAE'])/n, ), 
    r'$P=%.2f$' % ((r1['count']*r1['P']+r1['count']*r2['MAE'])/n, ), 
    r'$THRESH=%.2f$%%' % ((r1['count']*r1['thresh']+r1['thresh']*r2['MAE'])/n, )))
ax.text(0.015, 0.985, textstr,horizontalalignment='left',verticalalignment='top',transform=ax.transAxes)
fig.savefig('E:\wp3\Validation\LAICCRS.png', bbox_inches='tight')

# %%
fig = plt.figure();

r1 = plotDataDGBOVFLIGHT(GBOVDataDASFCCRS,GBOVDataLAICCRS,'LAI_Warren','sampleLAI',50,'E:\wp3\Validation\LAIGBOV.png',1000,fig)
r2 = plotDataDCCRS2FLIGHT(ccrsDataDASFCCRS,ccrsDataLAICCRS,'PAICEV61','sampleLAI',50,'E:\wp3\Validation\LAIGBOV.png',1000,fig)

ax = plt.gca()
n = r1['count'] + r2['count']
textstr = '\n'.join(( 
    r'$N=%d$' % n, 
    r'$MAE=%.2f$' % ((r1['count']*r1['MAE']+r1['count']*r2['MAE'])/n, ), 
    r'$U=%.2f$' % ((r1['count']*r1['U']+r1['count']*r2['MAE'])/n, ), 
    r'$A=%.2f$' % ((r1['count']*r1['A']+r1['count']*r2['MAE'])/n, ), 
    r'$P=%.2f$' % ((r1['count']*r1['P']+r1['count']*r2['MAE'])/n, ), 
    r'$THRESH=%.2f$%%' % ((r1['count']*r1['thresh']+r1['thresh']*r2['MAE'])/n, )))
ax.text(0.015, 0.985, textstr,horizontalalignment='left',verticalalignment='top',transform=ax.transAxes)
fig.savefig('E:\wp3\Validation\LAICCRSFLIGHT.png', bbox_inches='tight')

# %%
fig = plt.figure();
r1=plotDataDGBOV(GBOVDataDASFCCRS,GBOVDatafAPARSL2P,'FIPAR','samplefAPAR',50,'E:\wp3\Validation\FCOVER3.png',0,fig)
r2=plotDataDCCRS2(ccrsDataDASFCCRS,ccrsDatafAPARSL2P,'Daily_Integrated_Black_Sky_fAPAR','samplefAPAR',50,'E:\wp3\Validation\FCOVER3.png',0,fig)

ax = plt.gca()
n = r1['count'] + r2['count']
textstr = '\n'.join(( 
     r'$N=%d$' % n, 
     r'$MAE=%.2f$' % ((r1['count']*r1['MAE']+r1['count']*r2['MAE'])/n, ), 
     r'$U=%.2f$' % ((r1['count']*r1['U']+r1['count']*r2['MAE'])/n, ), 
     r'$A=%.2f$' % ((r1['count']*r1['A']+r1['count']*r2['MAE'])/n, ), 
     r'$P=%.2f$' % ((r1['count']*r1['P']+r1['count']*r2['MAE'])/n, ), 
     r'$THRESH=%.2f$%%' % ((r1['count']*r1['thresh']+r1['thresh']*r2['MAE'])/n, )))
ax.text(0.015, 0.985, textstr,horizontalalignment='left',verticalalignment='top',transform=ax.transAxes)
fig.savefig('E:/wp3/Validation/fAPARSL2P.png', bbox_inches='tight')

# %%
fig = plt.figure();
r1=plotDataDGBOV(GBOVDataDASFCCRS,GBOVDatafAPARCCRS,'FIPAR','samplefAPAR',50,'E:\wp3\Validation\FCOVER3.png',0,fig)
r2=plotDataDCCRS2(ccrsDataDASFCCRS,ccrsDatafAPARCCRS,'Daily_Integrated_Black_Sky_fAPAR','samplefAPAR',50,'E:\wp3\Validation\FCOVER3.png',0,fig)

ax = plt.gca()
n = r1['count'] + r2['count']
textstr = '\n'.join(( 
    r'$N=%d$' % n, 
    r'$MAE=%.2f$' % ((r1['count']*r1['MAE']+r1['count']*r2['MAE'])/n, ), 
    r'$U=%.2f$' % ((r1['count']*r1['U']+r1['count']*r2['MAE'])/n, ), 
    r'$A=%.2f$' % ((r1['count']*r1['A']+r1['count']*r2['MAE'])/n, ), 
    r'$P=%.2f$' % ((r1['count']*r1['P']+r1['count']*r2['MAE'])/n, ), 
    r'$THRESH=%.2f$%%' % ((r1['count']*r1['thresh']+r1['thresh']*r2['MAE'])/n, )))
ax.text(0.015, 0.985, textstr,horizontalalignment='left',verticalalignment='top',transform=ax.transAxes)
fig.savefig('E:/wp3/Validation/fAPARCCRS.png', bbox_inches='tight')

# %%
fig = plt.figure();

r1 = plotDataDGBOV(GBOVDataDASFCCRS,GBOVDatafAPARCCRS,'FIPAR','samplefAPAR',50,'E:\wp3\Validation\LAIGBOV.png',1000,fig)
r2 = plotDataDCCRS2(ccrsDataDASFCCRS,ccrsDatafAPARCCRS,'Daily_Integrated_Black_Sky_fAPAR','samplefAPAR',50,'E:\wp3\Validation\LAIGBOV.png',1000,fig)

ax = plt.gca()
n = r1['count'] + r2['count']
textstr = '\n'.join(( 
    r'$N=%d$' % n, 
    r'$MAE=%.2f$' % ((r1['count']*r1['MAE']+r1['count']*r2['MAE'])/n, ), 
    r'$U=%.2f$' % ((r1['count']*r1['U']+r1['count']*r2['MAE'])/n, ), 
    r'$A=%.2f$' % ((r1['count']*r1['A']+r1['count']*r2['MAE'])/n, ), 
    r'$P=%.2f$' % ((r1['count']*r1['P']+r1['count']*r2['MAE'])/n, ), 
    r'$THRESH=%.2f$%%' % ((r1['count']*r1['thresh']+r1['thresh']*r2['MAE'])/n, )))
ax.text(0.015, 0.985, textstr,horizontalalignment='left',verticalalignment='top',transform=ax.transAxes)
fig.savefig('E:/wp3/Validation/fAPARCCRSFLIGHT.png', bbox_inches='tight')
